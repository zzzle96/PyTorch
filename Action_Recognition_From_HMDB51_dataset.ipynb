# %% [markdown]
# <a href="https://colab.research.google.com/github/zzzle96/PyTorch/blob/master/Action_Recognition_From_HMDB51_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies for video module in pytorch to work
! apt-get install libavformat-dev libavdevice-dev
! pip install av==6.2.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libavdevice-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# libavformat-dev is already the newest version (7:3.4.8-0ubuntu0.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# Collecting av==6.2.0
#   Using cached https://files.pythonhosted.org/packages/84/77/0be0fdaa3b7912c184705a4545ae6f1e9e47ab9e3834a3ef5caf2d7ca1e7/av-6.2.0.tar.gz
# Building wheels for collected packages: av
# av
#   Building wheel for av (setup.py) ... done
#   Created wheel for av: filename=av-6.2.0-cp36-cp36m-linux_x86_64.whl size=5003062 sha256=1364fa01f4fe140693e186c29963d39fe961fb910ceac3524e10c10b20eea026
#   Stored in directory: /root/.cache/pip/wheels/2f/c1/b2/05e83d944cde5df317e4542082d67756ec4224c7885aee2d66
# Successfully built av
# Installing collected packages: av
# Successfully installed av-6.2.0

# %%
# Download HMDB51 data and splits from serre lab website
! wget http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
! wget http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Out:
# --2020-09-13 18:38:51--  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Resolving serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)... 128.148.254.114
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar [following]
# --2020-09-13 18:38:51--  https://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/hmdb51_org.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2124008126 (2.0G)
# Saving to: ‘hmdb51_org.rar’
#
# hmdb51_org.rar      100%[===================>]   1.98G  42.0MB/s    in 61s
#
# 2020-09-13 18:39:53 (33.2 MB/s) - ‘hmdb51_org.rar’ saved [2124008126/2124008126]
#
# --2020-09-13 18:39:53--  http://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Resolving serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)... 128.148.254.114
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar [following]
# --2020-09-13 18:39:53--  https://serre-lab.clps.brown.edu/wp-content/uploads/2013/10/test_train_splits.rar
# Connecting to serre-lab.clps.brown.edu (serre-lab.clps.brown.edu)|128.148.254.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 199521 (195K)
# Saving to: ‘test_train_splits.rar’
#
# test_train_splits.r 100%[===================>] 194.84K   714KB/s    in 0.3s
#
# 2020-09-13 18:39:54 (714 KB/s) - ‘test_train_splits.rar’ saved [199521/199521]

# %%
# Import required modules ...

import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import random_split, DataLoader
from torch.optim.lr_scheduler import StepLR
import torchvision
from torchvision import get_video_backend
from torchvision.models.video import r3d_18 
from torchvision import transforms
import os
from tqdm.auto import tqdm
import numpy as np
import time
#import av
import random
#print(f"PyAV version -- {av.__version__}")

SEED = 491
torch.manual_seed(SEED)

from collections import OrderedDict
import warnings
warnings.filterwarnings('ignore')

#run_av_diagnostics()

# %%
# Extract and organize video data..
! mkdir -p video_data test_train_splits
! unrar e test_train_splits.rar test_train_splits
! rm test_train_splits.rar
! unrar e hmdb51_org.rar 
! rm hmdb51_org.rar
! mv *.rar video_data
for files in os.listdir('video_data'):
    foldername = files.split('.')[0]
    os.system("mkdir -p video_data/" + foldername)
    os.system("unrar e video_data/"+ files + " video_data/"+foldername)

! rm video_data/*.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from test_train_splits.rar
#
#
# Would you like to replace the existing file test_train_splits/brush_hair_test_split1.txt
#   7194 bytes, modified on 2010-12-13 16:16
# with a new one
#   7194 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/brush_hair_test_split2.txt
#   7194 bytes, modified on 2010-12-13 16:16
# with a new one
#   7194 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/brush_hair_test_split3.txt
#   7194 bytes, modified on 2010-12-13 16:16
# with a new one
#   7194 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/cartwheel_test_split1.txt
#   6600 bytes, modified on 2010-12-13 16:14
# with a new one
#   6600 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/cartwheel_test_split2.txt
#   6600 bytes, modified on 2010-12-13 16:14
# with a new one
#   6600 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/cartwheel_test_split3.txt
#   6600 bytes, modified on 2010-12-13 16:14
# with a new one
#   6600 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/catch_test_split1.txt
#   6658 bytes, modified on 2010-12-13 20:23
# with a new one
#   6658 bytes, modified on 2010-12-13 20:23
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/catch_test_split2.txt
#   6658 bytes, modified on 2010-12-13 20:23
# with a new one
#   6658 bytes, modified on 2010-12-13 20:23
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/catch_test_split3.txt
#   6658 bytes, modified on 2010-12-13 20:23
# with a new one
#   6658 bytes, modified on 2010-12-13 20:23
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/chew_test_split1.txt
#   5881 bytes, modified on 2010-12-13 20:24
# with a new one
#   5881 bytes, modified on 2010-12-13 20:24
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/chew_test_split2.txt
#   5881 bytes, modified on 2010-12-13 20:24
# with a new one
#   5881 bytes, modified on 2010-12-13 20:24
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/chew_test_split3.txt
#   5881 bytes, modified on 2010-12-13 20:24
# with a new one
#   5881 bytes, modified on 2010-12-13 20:24
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/clap_test_split1.txt
#   7008 bytes, modified on 2010-12-13 20:26
# with a new one
#   7008 bytes, modified on 2010-12-13 20:26
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/clap_test_split2.txt
#   7008 bytes, modified on 2010-12-13 20:26
# with a new one
#   7008 bytes, modified on 2010-12-13 20:26
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/clap_test_split3.txt
#   7008 bytes, modified on 2010-12-13 20:26
# with a new one
#   7008 bytes, modified on 2010-12-13 20:26
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/climb_stairs_test_split1.txt
#   8957 bytes, modified on 2010-12-13 16:21
# with a new one
#   8957 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/climb_stairs_test_split2.txt
#   8957 bytes, modified on 2010-12-13 16:21
# with a new one
#   8957 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/climb_stairs_test_split3.txt
#   8957 bytes, modified on 2010-12-13 16:21
# with a new one
#   8957 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/climb_test_split1.txt
#   7305 bytes, modified on 2010-12-13 16:14
# with a new one
#   7305 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/climb_test_split2.txt
#   7305 bytes, modified on 2010-12-13 16:14
# with a new one
#   7305 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/climb_test_split3.txt
#   7305 bytes, modified on 2010-12-13 16:14
# with a new one
#   7305 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/dive_test_split1.txt
#   7198 bytes, modified on 2010-12-13 16:19
# with a new one
#   7198 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/dive_test_split2.txt
#   7198 bytes, modified on 2010-12-13 16:19
# with a new one
#   7198 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/dive_test_split3.txt
#   7198 bytes, modified on 2010-12-13 16:19
# with a new one
#   7198 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/draw_sword_test_split1.txt
#   7053 bytes, modified on 2010-12-13 16:18
# with a new one
#   7053 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/draw_sword_test_split2.txt
#   7053 bytes, modified on 2010-12-13 16:18
# with a new one
#   7053 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/draw_sword_test_split3.txt
#   7053 bytes, modified on 2010-12-13 16:18
# with a new one
#   7053 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/dribble_test_split1.txt
#  11596 bytes, modified on 2010-12-13 16:16
# with a new one
#  11596 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/dribble_test_split2.txt
#  11596 bytes, modified on 2010-12-13 16:16
# with a new one
#  11596 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/dribble_test_split3.txt
#  11596 bytes, modified on 2010-12-13 16:16
# with a new one
#  11596 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/drink_test_split1.txt
#   7698 bytes, modified on 2010-12-13 16:14
# with a new one
#   7698 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/drink_test_split2.txt
#   7698 bytes, modified on 2010-12-13 16:14
# with a new one
#   7698 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/drink_test_split3.txt
#   7698 bytes, modified on 2010-12-13 16:14
# with a new one
#   7698 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/eat_test_split1.txt
#   4930 bytes, modified on 2010-12-13 16:21
# with a new one
#   4930 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/eat_test_split2.txt
#   4930 bytes, modified on 2010-12-13 16:21
# with a new one
#   4930 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/eat_test_split3.txt
#   4930 bytes, modified on 2010-12-13 16:21
# with a new one
#   4930 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/fall_floor_test_split1.txt
#   7051 bytes, modified on 2010-12-13 16:19
# with a new one
#   7051 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/fall_floor_test_split2.txt
#   7051 bytes, modified on 2010-12-13 16:19
# with a new one
#   7051 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/fall_floor_test_split3.txt
#   7051 bytes, modified on 2010-12-13 16:19
# with a new one
#   7051 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/fencing_test_split1.txt
#   7387 bytes, modified on 2010-12-13 16:17
# with a new one
#   7387 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/fencing_test_split2.txt
#   7387 bytes, modified on 2010-12-13 16:17
# with a new one
#   7387 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/fencing_test_split3.txt
#   7387 bytes, modified on 2010-12-13 16:17
# with a new one
#   7387 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/flic_flac_test_split1.txt
#   6339 bytes, modified on 2010-12-13 16:16
# with a new one
#   6339 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/flic_flac_test_split2.txt
#   6339 bytes, modified on 2010-12-13 16:16
# with a new one
#   6339 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/flic_flac_test_split3.txt
#   6339 bytes, modified on 2010-12-13 16:16
# with a new one
#   6339 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/golf_test_split1.txt
#   5817 bytes, modified on 2010-12-13 16:15
# with a new one
#   5817 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/golf_test_split2.txt
#   5817 bytes, modified on 2010-12-13 16:15
# with a new one
#   5817 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/golf_test_split3.txt
#   5817 bytes, modified on 2010-12-13 16:15
# with a new one
#   5817 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/handstand_test_split1.txt
#   7046 bytes, modified on 2010-12-13 16:21
# with a new one
#   7046 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/handstand_test_split2.txt
#   7046 bytes, modified on 2010-12-13 16:21
# with a new one
#   7046 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/handstand_test_split3.txt
#   7046 bytes, modified on 2010-12-13 16:21
# with a new one
#   7046 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/hit_test_split1.txt
#   6993 bytes, modified on 2010-12-13 16:19
# with a new one
#   6993 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/hit_test_split2.txt
#   6993 bytes, modified on 2010-12-13 16:19
# with a new one
#   6993 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/hit_test_split3.txt
#   6993 bytes, modified on 2010-12-13 16:19
# with a new one
#   6993 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/hug_test_split1.txt
#   8403 bytes, modified on 2010-12-13 16:18
# with a new one
#   8403 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/hug_test_split2.txt
#   8403 bytes, modified on 2010-12-13 16:18
# with a new one
#   8403 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/hug_test_split3.txt
#   8403 bytes, modified on 2010-12-13 16:18
# with a new one
#   8403 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/jump_test_split1.txt
#   8397 bytes, modified on 2010-12-13 16:16
# with a new one
#   8397 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/jump_test_split2.txt
#   8397 bytes, modified on 2010-12-13 16:16
# with a new one
#   8397 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/jump_test_split3.txt
#   8397 bytes, modified on 2010-12-13 16:16
# with a new one
#   8397 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kick_ball_test_split1.txt
#   8636 bytes, modified on 2010-12-13 16:21
# with a new one
#   8636 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kick_ball_test_split2.txt
#   8636 bytes, modified on 2010-12-13 16:21
# with a new one
#   8636 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kick_ball_test_split3.txt
#   8636 bytes, modified on 2010-12-13 16:21
# with a new one
#   8636 bytes, modified on 2010-12-13 16:21
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kick_test_split1.txt
#   7314 bytes, modified on 2010-12-13 16:15
# with a new one
#   7314 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kick_test_split2.txt
#   7314 bytes, modified on 2010-12-13 16:15
# with a new one
#   7314 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kick_test_split3.txt
#   7314 bytes, modified on 2010-12-13 16:15
# with a new one
#   7314 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kiss_test_split1.txt
#   5421 bytes, modified on 2010-12-13 16:20
# with a new one
#   5421 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kiss_test_split2.txt
#   5421 bytes, modified on 2010-12-13 16:20
# with a new one
#   5421 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/kiss_test_split3.txt
#   5421 bytes, modified on 2010-12-13 16:20
# with a new one
#   5421 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/laugh_test_split1.txt
#   7301 bytes, modified on 2010-12-13 16:16
# with a new one
#   7301 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/laugh_test_split2.txt
#   7301 bytes, modified on 2010-12-13 16:16
# with a new one
#   7301 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/laugh_test_split3.txt
#   7301 bytes, modified on 2010-12-13 16:16
# with a new one
#   7301 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pick_test_split1.txt
#   5853 bytes, modified on 2010-12-13 16:15
# with a new one
#   5853 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pick_test_split2.txt
#   5853 bytes, modified on 2010-12-13 16:15
# with a new one
#   5853 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pick_test_split3.txt
#   5853 bytes, modified on 2010-12-13 16:15
# with a new one
#   5853 bytes, modified on 2010-12-13 16:15
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pour_test_split1.txt
#   6798 bytes, modified on 2010-12-13 16:19
# with a new one
#   6798 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pour_test_split2.txt
#   6798 bytes, modified on 2010-12-13 16:19
# with a new one
#   6798 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pour_test_split3.txt
#   6798 bytes, modified on 2010-12-13 16:19
# with a new one
#   6798 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pullup_test_split1.txt
#   6254 bytes, modified on 2010-12-13 16:17
# with a new one
#   6254 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pullup_test_split2.txt
#   6254 bytes, modified on 2010-12-13 16:17
# with a new one
#   6254 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pullup_test_split3.txt
#   6254 bytes, modified on 2010-12-13 16:17
# with a new one
#   6254 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/punch_test_split1.txt
#   7388 bytes, modified on 2010-12-13 16:16
# with a new one
#   7388 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/punch_test_split2.txt
#   7388 bytes, modified on 2010-12-13 16:16
# with a new one
#   7388 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/punch_test_split3.txt
#   7388 bytes, modified on 2010-12-13 16:16
# with a new one
#   7388 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pushup_test_split1.txt
#   6480 bytes, modified on 2010-12-13 16:18
# with a new one
#   6480 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pushup_test_split2.txt
#   6480 bytes, modified on 2010-12-13 16:18
# with a new one
#   6480 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/pushup_test_split3.txt
#   6480 bytes, modified on 2010-12-13 16:18
# with a new one
#   6480 bytes, modified on 2010-12-13 16:18
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/push_test_split1.txt
#   6529 bytes, modified on 2010-12-13 16:14
# with a new one
#   6529 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/push_test_split2.txt
#   6529 bytes, modified on 2010-12-13 16:14
# with a new one
#   6529 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/push_test_split3.txt
#   6529 bytes, modified on 2010-12-13 16:14
# with a new one
#   6529 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/ride_bike_test_split1.txt
#   7402 bytes, modified on 2010-12-13 16:16
# with a new one
#   7402 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/ride_bike_test_split2.txt
#   7402 bytes, modified on 2010-12-13 16:16
# with a new one
#   7402 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/ride_bike_test_split3.txt
#   7402 bytes, modified on 2010-12-13 16:16
# with a new one
#   7402 bytes, modified on 2010-12-13 16:16
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/ride_horse_test_split1.txt
#   6195 bytes, modified on 2010-12-13 16:14
# with a new one
#   6195 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/ride_horse_test_split2.txt
#   6195 bytes, modified on 2010-12-13 16:14
# with a new one
#   6195 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/ride_horse_test_split3.txt
#   6195 bytes, modified on 2010-12-13 16:14
# with a new one
#   6195 bytes, modified on 2010-12-13 16:14
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/run_test_split1.txt
#  10685 bytes, modified on 2010-12-13 16:20
# with a new one
#  10685 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/run_test_split2.txt
#  10685 bytes, modified on 2010-12-13 16:20
# with a new one
#  10685 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/run_test_split3.txt
#  10685 bytes, modified on 2010-12-13 16:20
# with a new one
#  10685 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shake_hands_test_split1.txt
#  12779 bytes, modified on 2010-12-13 16:19
# with a new one
#  12779 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shake_hands_test_split2.txt
#  12779 bytes, modified on 2010-12-13 16:19
# with a new one
#  12779 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shake_hands_test_split3.txt
#  12779 bytes, modified on 2010-12-13 16:19
# with a new one
#  12779 bytes, modified on 2010-12-13 16:19
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_ball_test_split1.txt
#   8680 bytes, modified on 2010-12-13 16:17
# with a new one
#   8680 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_ball_test_split2.txt
#   8680 bytes, modified on 2010-12-13 16:17
# with a new one
#   8680 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_ball_test_split3.txt
#   8680 bytes, modified on 2010-12-13 16:17
# with a new one
#   8680 bytes, modified on 2010-12-13 16:17
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_bow_test_split1.txt
#   6221 bytes, modified on 2010-12-13 16:22
# with a new one
#   6221 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_bow_test_split2.txt
#   6221 bytes, modified on 2010-12-13 16:22
# with a new one
#   6221 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_bow_test_split3.txt
#   6221 bytes, modified on 2010-12-13 16:22
# with a new one
#   6221 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_gun_test_split1.txt
#   5260 bytes, modified on 2010-12-13 16:20
# with a new one
#   5260 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_gun_test_split2.txt
#   5260 bytes, modified on 2010-12-13 16:20
# with a new one
#   5260 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/shoot_gun_test_split3.txt
#   5260 bytes, modified on 2010-12-13 16:20
# with a new one
#   5260 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/situp_test_split1.txt
#   7088 bytes, modified on 2010-12-13 16:20
# with a new one
#   7088 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/situp_test_split2.txt
#   7088 bytes, modified on 2010-12-13 16:20
# with a new one
#   7088 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/situp_test_split3.txt
#   7088 bytes, modified on 2010-12-13 16:20
# with a new one
#   7088 bytes, modified on 2010-12-13 16:20
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/sit_test_split1.txt
#   6518 bytes, modified on 2010-12-13 16:22
# with a new one
#   6518 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/sit_test_split2.txt
#   6518 bytes, modified on 2010-12-13 16:22
# with a new one
#   6518 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/sit_test_split3.txt
#   6518 bytes, modified on 2010-12-13 16:22
# with a new one
#   6518 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/smile_test_split1.txt
#   5252 bytes, modified on 2010-12-13 16:29
# with a new one
#   5252 bytes, modified on 2010-12-13 16:29
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/smile_test_split2.txt
#   5252 bytes, modified on 2010-12-13 16:29
# with a new one
#   5252 bytes, modified on 2010-12-13 16:29
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/smile_test_split3.txt
#   5252 bytes, modified on 2010-12-13 16:29
# with a new one
#   5252 bytes, modified on 2010-12-13 16:29
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/smoke_test_split1.txt
#   5396 bytes, modified on 2010-12-13 16:22
# with a new one
#   5396 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/smoke_test_split2.txt
#   5396 bytes, modified on 2010-12-13 16:22
# with a new one
#   5396 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit n
#
#
# Would you like to replace the existing file test_train_splits/smoke_test_split3.txt
#   5396 bytes, modified on 2010-12-13 16:22
# with a new one
#   5396 bytes, modified on 2010-12-13 16:22
#
# [Y]es, [N]o, [A]ll, n[E]ver, [R]ename, [Q]uit a
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from hmdb51_org.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
# diagnostics for PyAV installation. For now version 6.2.0 works 
def run_av_diagnostics():
    import av
    av.open("video_data/brush_hair/Aussie_Brunette_Brushing_Hair_II_brush_hair_u_nm_np1_ba_goo_4.avi")
    print(get_video_backend())
    av.logging.set_level(av.logging.ERROR)
    if not hasattr(av.video.frame.VideoFrame, 'pict_type'):
      print("Nah")

run_av_diagnostics()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-4b11402948ea> in <module>()
#       8       print("Nah")
#       9
# ---> 10 run_av_diagnostics()
#
# <ipython-input-9-4b11402948ea> in run_av_diagnostics()
#       1 # diagnostics for PyAV installation. For now version 6.2.0 works
#       2 def run_av_diagnostics():
# ----> 3     import av
#       4     av.open("video_data/brush_hair/Aussie_Brunette_Brushing_Hair_II_brush_hair_u_nm_np1_ba_goo_4.avi")
#       5     print(get_video_backend())
#
# ModuleNotFoundError: No module named 'av'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# memory footprint support libraries/code
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize

import psutil
import humanize
import os
import GPUtil as GPU

GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
    process = psutil.Process(os.getpid())
    print("Gen RAM Free: " + humanize.naturalsize(psutil.virtual_memory().available), " |     Proc size: " + humanize.naturalsize(process.memory_info().rss))
    print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total     {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()

# %%
# download video transformation functions from below link
! wget https://raw.githubusercontent.com/pytorch/vision/6de158c473b83cf43344a0651d7c01128c7850e6/references/video_classification/transforms.py
import transforms as T
# Out:
# --2020-04-11 12:25:12--  https://raw.githubusercontent.com/pytorch/vision/6de158c473b83cf43344a0651d7c01128c7850e6/references/video_classification/transforms.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3102 (3.0K) [text/plain]
# Saving to: ‘transforms.py’
#
# transforms.py       100%[===================>]   3.03K  --.-KB/s    in 0s
#
# 2020-04-11 12:25:12 (54.9 MB/s) - ‘transforms.py’ saved [3102/3102]

# %%
# set up a sample pytorch class to check if it works
class Model(nn.Module):
  def __init__(self):
      super(Model, self).__init__()
      self.base_model = nn.Sequential(*list(r3d_18(pretrained=False).children())[:-1])
      self.fc1 = nn.Linear(512, 51)

  def forward(self, x):
      out = self.base_model(x).squeeze(4).squeeze(3).squeeze(2)
      print("size after pretrained model ", out.size())
      out = torch.log_softmax(self.fc1(out), dim=1)
      return out

check = Model().cuda()
out = check(torch.randn(16, 3 , 8, 112,112).cuda())
out.size()

# %%
class AverageMeter(object):
    """
    Computes and stores the average and current value
    """
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def update_acc(self, val, n=1):
        self.val = val/n
        self.sum += val
        self.count += n
        self.avg = self.sum / self.count

# %%
# define model using PyTorch
class VideoRecog_Model(nn.Module):
  def __init__(self):
      super(VideoRecog_Model, self).__init__()
      self.base_model = nn.Sequential(*list(r3d_18(pretrained=True).children())[:-1])
      self.fc1 = nn.Linear(512, 51)
      self.fc2 = nn.Linear(51, 51) 
      self.dropout = nn.Dropout2d(0.3) 

  def forward(self, x):
      out = self.base_model(x).squeeze(4).squeeze(3).squeeze(2) # output of base model is bs x 512 x 1 x 1 x 1
      out = F.relu(self.fc1(out)) 
      out = self.dropout(out) 
      out = torch.log_softmax(self.fc2(out), dim=1)
      return out

# %%
def train(config, model, loader, optimizer, epoch):
    model.train()
    config = {}
    config['log_interval'] = 100
    correct = 0
    total_loss = 0.0
    flag = 0
    Loss, Acc = AverageMeter(), AverageMeter()
    start = time.time()
    for batch_id, data in enumerate(loader):
        data, target = data[0], data[-1]
        # print("here")

        if torch.cuda.is_available():
           data = data.cuda()
           target = target.cuda()

        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        total_loss += loss.item()
        loss.backward()
        optimizer.step()

        Loss.update(loss.item(), data.size(0))

        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        num_corrects = pred.eq(target.view_as(pred)).sum().item()
        correct += num_corrects

        Acc.update_acc(num_corrects, data.size(0))

        if flag!= 0 and batch_id%config['log_interval'] == 0:
           print('Train Epoch: {} Batch [{}/{} ({:.0f}%)]\tLoss: {:.6f} Accuracy: {}/{} ({:.0f})%'.format(
                epoch, batch_id * len(data), len(loader.dataset),
                100. * batch_id / len(loader), Loss.avg, correct, Acc.count, 100. * Acc.avg))
        flag = 1

    #total_loss /= len(loader.dataset) 
    print('Train Epoch: {} Average Loss: {:.6f} Average Accuracy: {}/{} ({:.0f})%'.format(
         epoch, Loss.avg, correct, Acc.count, 100. * Acc.avg ))
    print(f"Takes {time.time() - start}")

# %%
def test(config, model, loader, text='Validation'):
    model.eval()
    correct = 0
    total_loss = 0.0
    Loss, Acc = AverageMeter(), AverageMeter()
    with torch.no_grad():
         for batch_id, data in enumerate(loader):
             data, target = data[0], data[-1]

             if torch.cuda.is_available():
                data = data.cuda()
                target = target.cuda()

             output = model(data)
             loss = F.nll_loss(output, target)
             total_loss += loss.item()

             Loss.update(loss.item(), data.size(0))

             pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
             num_corrects = pred.eq(target.view_as(pred)).sum().item()
             correct += num_corrects

             Acc.update_acc(num_corrects, data.size(0))
           
    total_loss /= len(loader.dataset)
    print(text + ' Average Loss: {:.6f} Average Accuracy: {}/{} ({:.0f})%'.format(
         Loss.avg, correct, Acc.count , 100. * Acc.avg ))

# %%
# Datasets and Dataloaders for model training ..

val_split = 0.05
num_frames = 16 # 16
clip_steps = 50
num_workers = 8
pin_memory = True
train_tfms = torchvision.transforms.Compose([
                                 T.ToFloatTensorInZeroOne(),
                                 T.Resize((128, 171)),
                                 T.RandomHorizontalFlip(),
                                 T.Normalize(mean=[0.43216, 0.394666, 0.37645], std=[0.22803, 0.22145, 0.216989]),
                                 T.RandomCrop((112, 112))
                               ])  
test_tfms =  torchvision.transforms.Compose([
                                             T.ToFloatTensorInZeroOne(),
                                             T.Resize((128, 171)),
                                             T.Normalize(mean=[0.43216, 0.394666, 0.37645], std=[0.22803, 0.22145, 0.216989]),
                                             T.CenterCrop((112, 112))
                                             ])
hmdb51_train = torchvision.datasets.HMDB51('video_data/', 'test_train_splits/', num_frames,
                                                step_between_clips = clip_steps, fold=1, train=True,
                                                transform=train_tfms, num_workers=num_workers)


hmdb51_test = torchvision.datasets.HMDB51('video_data/', 'test_train_splits/', num_frames,
                                                step_between_clips = clip_steps, fold=1, train=False,
                                                transform=test_tfms, num_workers=num_workers)
      
total_train_samples = len(hmdb51_train)
total_val_samples = round(val_split * total_train_samples)

print(f"number of train samples {total_train_samples}")
print(f"number of validation samples {total_val_samples}")
print(f"number of test samples {len(hmdb51_test)}")
# Out:
# HBox(children=(IntProgress(value=0, max=423), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=423), HTML(value='')))
# number of train samples 7754
# number of validation samples 388
# number of test samples 3234

# %%
bs = 4
lr = 1e-2
gamma = 0.7
total_epochs = 10
config = {}
num_workers = 0

kwargs = {'num_workers':num_workers, 'pin_memory':True} if torch.cuda.is_available() else {'num_workers':num_workers}
#kwargs = {'num_workers':num_workers}
#kwargs = {}

hmdb51_train_v1, hmdb51_val_v1 = random_split(hmdb51_train, [total_train_samples - total_val_samples,
                                                                       total_val_samples])

#hmdb51_train_v1.video_clips.compute_clips(16, 1, frame_rate=30)
#hmdb51_val_v1.video_clips.compute_clips(16, 1, frame_rate=30)
#hmdb51_test.video_clips.compute_clips(16, 1, frame_rate=30)

#train_sampler = RandomClipSampler(hmdb51_train_v1.video_clips, 5)
#test_sampler = UniformClipSampler(hmdb51_test.video_clips, 5)
  
train_loader = DataLoader(hmdb51_train_v1, batch_size=bs, shuffle=True, **kwargs)
val_loader   = DataLoader(hmdb51_val_v1, batch_size=bs, shuffle=True, **kwargs)
test_loader  = DataLoader(hmdb51_test, batch_size=bs, shuffle=False, **kwargs)

model = VideoRecog_Model()

if torch.cuda.is_available():
   model = model.cuda()

optimizer = torch.optim.Adam(model.parameters(), lr=lr)

scheduler = StepLR(optimizer, step_size=1, gamma=gamma)